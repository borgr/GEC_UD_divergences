# %%
import re
import json

import pandas as pd

from collections import Counter, defaultdict
from pprint import pprint

# %%
def no_corrections(alignment_dict):
    return len(alignment_dict) == 1 and len(alignment_dict['X']) == 0

# %%
def align_tokens(m2_block):
    unc_sentence, *edits = m2_block.splitlines()
    unc_tokens = re.split(
        r'\s+',
        unc_sentence
    )[1:]
    alignment_dict = {}
    alignment_dict['X'] = [] # For additions

    spans_outputs = []
    for edit in edits:
        coords, _, out, *_ = edit.split('|||')
        i, j = list(
            map(
                int,
                coords.split()[1:]))
        spans_outputs.append((
            (i,j),
            out))
    
    spans_outputs.sort()
    spans   = [el[0] for el in spans_outputs]
    outputs = [el[1] for el in spans_outputs]
    
    # If the edit is one-to-one, we align the beginning
    # of the edit with output_token_num.
    # We also keep track of one-word additions (zero-length input
    # spans) and deletions (zero-length output sequences).
    # Otherwise we skip the span and increase output_token_num
    # by the length of the output sequence.
    last_span_end = 0
    output_token_num = 0
    for idx in range(len(spans)):
        i, j = spans[idx]
        if i > last_span_end:
            output_token_num += i-last_span_end # Move cursor by the number of
                                                # copied tokens.
        out = outputs[idx]
#         print(spans[idx], f"inp: {' '.join(unc_tokens[i:j])}", f"out: {out}")
        out_len = len(out.split())
        if i-j == 0: # Addition
            if out_len == 1:
                alignment_dict['X'].append({
                    'idx': output_token_num,
                    'inp': ' '.join(unc_tokens[i:j]),
                    'out': out # For testing
                })
            output_token_num += out_len
        elif out == '': # Deletion
            if j-i == 1:
                alignment_dict[i] = 'X'
        elif j-i == out_len == 1: # One-to-one replacement
            alignment_dict[i] = {
                'idx': output_token_num,
                'inp': ' '.join(unc_tokens[i:j]),
                'out': out
            }
            output_token_num += 1
        else: # Something else
            output_token_num += out_len
        last_span_end = j
    return alignment_dict

# %%
def print_sentences(unc_tokens, cor_tokens):
    for i, tok in enumerate(unc_tokens):
        print(f'{tok}[{i}]', end=' ')
    print()
    for i, tok in enumerate(cor_tokens):
        print(f'{tok}[{i}]', end=' ')
    print('\n')
    
def test_alignment(m2_block, cor):
    cor_tokens = re.split(
        r'\s+',
        cor
    )
    cor = ' '.join(cor_tokens)
    unc_tokens = re.split(
        r'\s+',
        m2_block.splitlines()[0]
    )[1:]
    unc = ' '.join(unc_tokens)
    alignment_dict = align_tokens(m2_block)
    
    for k, v in alignment_dict.items():
        if v == 'X': # Don't test deletions for now
            continue
        if k == 'X':
            for el in v:
                i = el['idx']
                out = el['out']
                if cor_tokens[i] != out:
                    raise ValueError(f'{k}->{i}')
        else:
            i = v['idx']
            out = v['out']
            if cor_tokens[i] != out:
                raise ValueError(f'{k}->{i}')

# %%
def extract_features(field):
    """Returns CONLLU formatted UD features as a dictionary.
    A typical feature string:
    
    Case=Nom|Degree=Pos|Gender=Fem|Number=Sing
    
    Features and values are assumed to be one-to-one.
    """
    if field == '_':
        return {}
    return {
        feature: value for feature, value in [el.split('=') for el in field.split('|')]
    }

# %%
def conll2graph(record):
    """Converts sentences described using CoNLL-U format
    (http://universaldependencies.org/format.html) to graphs.
    Returns a dictionary of nodes (wordforms, POS tags, and feautures
    indexed by line numbers) together with a graph of the dependencies
    encoded as adjacency lists of (node_key, relation_label,
    direction[up or down]) tuples."""
    graph = {}
    nodes = {}
    for line in record.splitlines():
        if line.startswith("#"):
            continue
        fields = line.strip("\n").split("\t")
        key = fields[0]
        # Ignore compound surface keys for aux, du, etc.
        # Ignore hidden additional nodes for orphan handling
        if "-" in key or "." in key:
            continue
        wordform = fields[1]
        pos = fields[3]
        parent = fields[6]
        relation = fields[7]
        features = extract_features(fields[5])
        nodes[key] = {
            "wordform": wordform,
            "pos": pos,
            "relation": relation,
            "parent": parent,
            "features": features
        }
        if key not in graph:
            graph[key] = []
        if parent not in graph:
            graph[parent] = []
        graph[key].append((parent, relation, "up"))
        graph[parent].append((key, relation, "down"))
    return (nodes, graph)

# %%
def extract_sentence(nodes):
    tmp = []
    for v in nodes.values():
        tmp.append(v['wordform'])
    return ' '.join(tmp)

# %%
# Look for corrected sentences where the output as per alignment
# is not the same as per the edit annotation.
corrected = 0
errors = 0
for part in [
    'dev',
    'train',
    'test'
]:
    with open(f'm2_files/RULEC-GEC.{part}.M2', 'r') as inp:
        m2_dev_blocks = inp.read().strip().split('\n\n')
    with open(f'preprocessing/RULEC-GEC.{part}.corrected', 'r') as inp:
        m2_dev_cor_blocks = inp.readlines()
    assert(len(m2_dev_blocks) == len(m2_dev_cor_blocks))
    corrected = 0
    errors = 0
    for i in range(len(m2_dev_blocks)):
        alignment_dict = align_tokens(m2_dev_blocks[i])
        if no_corrections(alignment_dict):
            continue
        try:
            test_alignment(
                m2_dev_blocks[i],
                m2_dev_cor_blocks[i]
            )
            corrected += 1
        except ValueError:
            errors += 1
        except IndexError:
            errors += 1

# %%
corrected
# Out:
# 2247

# %%
errors
# Out:
# 23

# %%
# Align with UD trees produced by UDPipe and compute stats

aligned_graphs = []

additions_pos_stats = Counter()
additions_rel_stats = Counter()
deletions_pos_stats = Counter()
deletions_rel_stats = Counter()

rel_mismatches = []
pos_mismatches = []
# A dict of lists per feature per POS
# defaultdict needs a constructor as an argument, hence
# the anonymous function for embedded subtyping.
feature_mismatches = defaultdict(lambda: defaultdict(list))

added_prons = []

# A counter for features only found in parses of words from 
# uncorrected sentences.
disappearing_features = defaultdict(list)

errors = 0

for part in [
    'dev',
    'train',
    'test'
]:
    with open(f'm2_files/RULEC-GEC.{part}.M2', 'r') as inp:
        m2_dev_blocks = inp.read().strip().split('\n\n')
    with open(f'after_udpipe/RULEC-GEC.{part}.rus.conllu') as inp:
        ud_blocks_unc = inp.read().strip().split('\n\n')
    with open(f'after_udpipe/RULEC-GEC.{part}.corrected.rus.conllu') as inp:
        ud_blocks_cor = inp.read().strip().split('\n\n')
        
    assert(len(m2_dev_blocks) == len(ud_blocks_unc) == len(ud_blocks_cor))
    
    
    for i in range(len(m2_dev_blocks)):
        alignment_dict = align_tokens(m2_dev_blocks[i])
        unc_n, unc_g = conll2graph(ud_blocks_unc[i])
        cor_n, cor_g = conll2graph(ud_blocks_cor[i])
        aligned_graphs.append({
            'inp_n': unc_n,
            'inp_g': unc_g,
            'out_n': cor_n,
            'out_g': cor_g,
            'align': alignment_dict
        })
        # We assume that there are no wise-ass node IDs and that
        # they are simply node indices starting from 1.
        for k, v in alignment_dict.items():
            if k == 'X':
                for el in v:
                    idx = str(el['idx']+1)
                    additions_pos_stats[cor_n[idx]['pos']] += 1
                    additions_rel_stats[cor_n[idx]['relation']] += 1
                    
                    # Record added pronouns
                    if cor_n[idx]['pos'] == 'PRON':
                        added_prons.append((extract_sentence(unc_n), extract_sentence(cor_n)))
            elif v == 'X':
                idx = str(k+1)
                deletions_pos_stats[unc_n[idx]['pos']] += 1
                deletions_rel_stats[unc_n[idx]['relation']] += 1
            else:
                idx1 = str(k+1)
                idx2 = str(v['idx']+1)
                pos1 = unc_n[idx1]['pos']
                try:
                    pos2 = cor_n[idx2]['pos']
                except KeyError: # Computed output_token_num not found in the UD tree
                                 # Probably due to some weirdness.
                    errors += 1
                    continue
                if pos1 != pos2:
                    pos_mismatches.append((pos1, pos2))
                else:
                    feats1 = unc_n[idx1]['features']
                    feats2 = cor_n[idx2]['features']
                    for k in feats1:
                        try:
                            if feats1[k] != feats2[k]:
                                feature_mismatches[pos1][k].append((feats1[k], feats2[k]))
                        except KeyError:
                            disappearing_features[pos1].append(
                                f"{unc_n[idx1]['wordform']}, {k}: {feats1[k]} -> {cor_n[idx2]['wordform']}"
                            )
                            continue
                rel1 = unc_n[idx1]['relation']
                rel2 = cor_n[idx2]['relation']
                if rel1 != rel2:
                    rel_mismatches.append((rel1, rel2))

# %%
errors
# Out:
# 5

# %%
len(added_prons)
# Out:
# 111

# %%
# Makes sense
disappearing_features
# Out:
# defaultdict(list,
#             {'VERB': ['зарождающиеся, Animacy: Inan -> зарождающееся',
#               'произвело, Gender: Neut -> оказали',
#               'говорит, Mood: Ind -> говорить',
#               'говорит, Number: Sing -> говорить',
#               'говорит, Person: 3 -> говорить',
#               'говорит, Tense: Pres -> говорить',
#               'появлявший, Gender: Masc -> проявлявшиеся',
#               'написано, Gender: Neut -> написаны',
#               'остается, Person: 3 -> остановилось',
#               'начинается, Person: 3 -> началась',
#               'желаемой, Gender: Fem -> желаемых',
#               'учатся, Mood: Ind -> учиться',
#               'учатся, Number: Plur -> учиться',
#               'учатся, Person: 3 -> учиться',
#               'учатся, Tense: Pres -> учиться',
#               'было, Gender: Neut -> были',
#               'грозил, Gender: Masc -> грозили',
#               'позвонит, Mood: Ind -> позвонить',
#               'позвонит, Number: Sing -> позвонить',
#               'позвонит, Person: 3 -> позвонить',
#               'позвонит, Tense: Fut -> позвонить',
#               'слышат, Mood: Ind -> услышать',
#               'слышат, Number: Plur -> услышать',
#               'слышат, Person: 3 -> услышать',
#               'слышат, Tense: Fut -> услышать',
#               'привык, Gender: Masc -> привыкли',
#               'соединяется, Mood: Ind -> связано',
#               'соединяется, Person: 3 -> связано',
#               'построит, Mood: Ind -> построить',
#               'построит, Number: Sing -> построить',
#               'построит, Person: 3 -> построить',
#               'построит, Tense: Fut -> построить',
#               'противоетаят, Gender: Masc -> противостоят',
#               'противоетаят, Variant: Short -> противостоят',
#               'жит, Mood: Ind -> жить',
#               'жит, Number: Sing -> жить',
#               'жит, Person: 3 -> жить',
#               'жит, Tense: Pres -> жить',
#               'убедит, Mood: Ind -> убедить',
#               'убедит, Number: Sing -> убедить',
#               'убедит, Person: 3 -> убедить',
#               'убедит, Tense: Fut -> убедить',
#               'принятым, Case: Ins -> усыновлен',
#               'понимает, Person: 3 -> понимали',
#               'пропагандироват, Mood: Ind -> пропагандировать',
#               'пропагандироват, Number: Plur -> пропагандировать',
#               'пропагандироват, Person: 3 -> пропагандировать',
#               'пропагандироват, Tense: Fut -> пропагандировать',
#               'схватит, Mood: Ind -> завоевать',
#               'схватит, Number: Sing -> завоевать',
#               'схватит, Person: 3 -> завоевать',
#               'схватит, Tense: Fut -> завоевать',
#               'бит, Mood: Ind -> бить',
#               'бит, Number: Sing -> бить',
#               'бит, Person: 3 -> бить',
#               'бит, Tense: Pres -> бить',
#               'определено, Gender: Neut -> определить',
#               'определено, Number: Sing -> определить',
#               'определено, Tense: Past -> определить',
#               'определено, Variant: Short -> определить',
#               'говорит, Mood: Ind -> говорить',
#               'говорит, Number: Sing -> говорить',
#               'говорит, Person: 3 -> говорить',
#               'говорит, Tense: Pres -> говорить',
#               'служит, Mood: Ind -> служить',
#               'служит, Number: Sing -> служить',
#               'служит, Person: 3 -> служить',
#               'служит, Tense: Pres -> служить',
#               'положен, Gender: Masc -> положены',
#               'проповедуют, Person: 3 -> проповедовали',
#               'формируют, Person: 3 -> формировали',
#               'обяснит, Mood: Ind -> объяснить',
#               'обяснит, Number: Sing -> объяснить',
#               'обяснит, Person: 3 -> объяснить',
#               'обяснит, Tense: Fut -> объяснить',
#               'относится, Mood: Ind -> относиться',
#               'относится, Number: Sing -> относиться',
#               'относится, Person: 3 -> относиться',
#               'относится, Tense: Pres -> относиться',
#               'задуматся, Mood: Ind -> задуматься',
#               'задуматся, Number: Plur -> задуматься',
#               'задуматся, Person: 3 -> задуматься',
#               'задуматся, Tense: Pres -> задуматься',
#               'показывала, Gender: Fem -> показывали',
#               'говорит, Mood: Ind -> говорить',
#               'говорит, Number: Sing -> говорить',
#               'говорит, Person: 3 -> говорить',
#               'говорит, Tense: Pres -> говорить',
#               'приходит, Mood: Ind -> прийти',
#               'приходит, Number: Sing -> прийти',
#               'приходит, Person: 3 -> прийти',
#               'приходит, Tense: Pres -> прийти',
#               'значил, Gender: Masc -> значит',
#               'использована, Gender: Fem -> используется',
#               'использована, Variant: Short -> используется',
#               'описывающий, Gender: Masc -> описывающие',
#               'боротся, Mood: Ind -> бороться',
#               'боротся, Number: Sing -> бороться',
#               'боротся, Person: 3 -> бороться',
#               'боротся, Tense: Pres -> бороться',
#               'описывающий, Gender: Masc -> описывающие',
#               'считается, Person: 3 -> считалось',
#               'описывающий, Gender: Masc -> описывающие',
#               'меняет, Mood: Ind -> поменять',
#               'меняет, Number: Sing -> поменять',
#               'меняет, Person: 3 -> поменять',
#               'меняет, Tense: Pres -> поменять',
#               'запрещен, Gender: Masc -> запрещается',
#               'запрещен, Variant: Short -> запрещается',
#               'строит, Mood: Ind -> строить',
#               'строит, Number: Sing -> строить',
#               'строит, Person: 3 -> строить',
#               'строит, Tense: Pres -> строить',
#               'могут, Person: 3 -> могли',
#               'основывался, Gender: Masc -> основывались',
#               'связаны, Variant: Short -> связанные',
#               'радоватся, Mood: Ind -> радоваться',
#               'радоватся, Number: Plur -> радоваться',
#               'радоватся, Person: 3 -> радоваться',
#               'радоватся, Tense: Fut -> радоваться',
#               'найте, Mood: Imp -> подыскивать',
#               'найте, Number: Plur -> подыскивать',
#               'найте, Person: 2 -> подыскивать',
#               'организуется, Mood: Ind -> организована',
#               'организуется, Person: 3 -> организована',
#               'ломается, Mood: Ind -> сломаться',
#               'ломается, Number: Sing -> сломаться',
#               'ломается, Person: 3 -> сломаться',
#               'ломается, Tense: Pres -> сломаться',
#               'видет, Mood: Ind -> видеть',
#               'видет, Number: Sing -> видеть',
#               'видет, Person: 3 -> видеть',
#               'видет, Tense: Pres -> видеть',
#               'заботится, Mood: Ind -> заботиться',
#               'заботится, Number: Sing -> заботиться',
#               'заботится, Person: 3 -> заботиться',
#               'заботится, Tense: Pres -> заботиться',
#               'убираетесь, Tense: Pres -> убирайтесь',
#               'интересуемся, Mood: Ind -> интересоваться',
#               'интересуемся, Number: Plur -> интересоваться',
#               'интересуемся, Person: 1 -> интересоваться',
#               'интересуемся, Tense: Pres -> интересоваться',
#               'платили, Mood: Ind -> платить',
#               'платили, Number: Plur -> платить',
#               'платили, Tense: Past -> платить',
#               'удалось, Gender: Neut -> задают',
#               'любит, Mood: Ind -> любить',
#               'любит, Number: Sing -> любить',
#               'любит, Person: 3 -> любить',
#               'любит, Tense: Pres -> любить',
#               'угадит, Mood: Ind -> угодить',
#               'угадит, Number: Sing -> угодить',
#               'угадит, Person: 3 -> угодить',
#               'угадит, Tense: Pres -> угодить',
#               'остаётсся, Gender: Masc -> остаётся',
#               'запрещен, Gender: Masc -> запрещается',
#               'запрещен, Variant: Short -> запрещается',
#               'отметит, Mood: Ind -> отметить',
#               'отметит, Number: Sing -> отметить',
#               'отметит, Person: 3 -> отметить',
#               'отметит, Tense: Fut -> отметить',
#               'имеет, Mood: Ind -> иметь',
#               'имеет, Number: Sing -> иметь',
#               'имеет, Person: 3 -> иметь',
#               'имеет, Tense: Pres -> иметь',
#               'освобождены, Variant: Short -> освобожденные',
#               'заметило, Gender: Neut -> заметили',
#               'занимала, Gender: Fem -> занимает',
#               'контрольировал, Gender: Masc -> контролировать',
#               'контрольировал, Mood: Ind -> контролировать',
#               'контрольировал, Number: Sing -> контролировать',
#               'контрольировал, Tense: Past -> контролировать',
#               'советуем, Mood: Ind -> советовать',
#               'советуем, Number: Plur -> советовать',
#               'советуем, Person: 1 -> советовать',
#               'советуем, Tense: Pres -> советовать',
#               'половим, Mood: Ind -> использовать',
#               'половим, Number: Plur -> использовать',
#               'половим, Person: 1 -> использовать',
#               'половим, Tense: Fut -> использовать',
#               'говорит, Mood: Ind -> сказать',
#               'говорит, Number: Sing -> сказать',
#               'говорит, Person: 3 -> сказать',
#               'говорит, Tense: Pres -> сказать',
#               'погиб, Gender: Masc -> погибну',
#               'дает, Mood: Ind -> давать',
#               'дает, Number: Sing -> давать',
#               'дает, Person: 3 -> давать',
#               'дает, Tense: Pres -> давать',
#               'может, Person: 3 -> могло',
#               'учится, Mood: Ind -> учиться',
#               'учится, Number: Sing -> учиться',
#               'учится, Person: 3 -> учиться',
#               'учится, Tense: Pres -> учиться',
#               'ассоциируемый, Gender: Masc -> ассоциируемые',
#               'окружающие, Animacy: Inan -> окружающую',
#               'отразится, Mood: Ind -> отразиться',
#               'отразится, Number: Sing -> отразиться',
#               'отразится, Person: 3 -> отразиться',
#               'отразится, Tense: Fut -> отразиться',
#               'померит, Mood: Ind -> измерить',
#               'померит, Number: Sing -> измерить',
#               'померит, Person: 3 -> измерить',
#               'померит, Tense: Fut -> измерить',
#               'перегружены, Variant: Short -> перегруженными',
#               'двигатся, Mood: Ind -> двигаться',
#               'двигатся, Number: Plur -> двигаться',
#               'двигатся, Person: 3 -> двигаться',
#               'двигатся, Tense: Pres -> двигаться',
#               'зависит, Mood: Ind -> зависеть',
#               'зависит, Number: Sing -> зависеть',
#               'зависит, Person: 3 -> зависеть',
#               'зависит, Tense: Pres -> зависеть',
#               'признают, Mood: Ind -> признать',
#               'признают, Number: Plur -> признать',
#               'признают, Person: 3 -> признать',
#               'признают, Tense: Pres -> признать',
#               'употребляет, Mood: Ind -> употреблять',
#               'употребляет, Number: Sing -> употреблять',
#               'употребляет, Person: 3 -> употреблять',
#               'употребляет, Tense: Pres -> употреблять',
#               'вылечит, Mood: Ind -> вылечить',
#               'вылечит, Number: Sing -> вылечить',
#               'вылечит, Person: 3 -> вылечить',
#               'вылечит, Tense: Fut -> вылечить',
#               'опубликованы, Variant: Short -> опубликованные',
#               'считающие, Case: Nom -> считает',
#               'сделано, Gender: Neut -> происходит',
#               'сделано, Variant: Short -> происходит',
#               'говорит, Mood: Ind -> говорить',
#               'говорит, Number: Sing -> говорить',
#               'говорит, Person: 3 -> говорить',
#               'говорит, Tense: Pres -> говорить',
#               'пользоватся, Mood: Ind -> пользоваться',
#               'пользоватся, Number: Plur -> пользоваться',
#               'пользоватся, Person: 3 -> пользоваться',
#               'пользоватся, Tense: Pres -> пользоваться',
#               'основан, Variant: Short -> основанный',
#               'переполнен, Variant: Short -> переполненном',
#               'пересмотрят, Mood: Ind -> пересматривать',
#               'пересмотрят, Number: Plur -> пересматривать',
#               'пересмотрят, Person: 3 -> пересматривать',
#               'пересмотрят, Tense: Fut -> пересматривать',
#               'есть, Mood: Ind -> съесть',
#               'есть, Number: Plur -> съесть',
#               'есть, Person: 3 -> съесть',
#               'есть, Tense: Pres -> съесть',
#               'согласится, Mood: Ind -> согласиться',
#               'согласится, Number: Sing -> согласиться',
#               'согласится, Person: 3 -> согласиться',
#               'согласится, Tense: Fut -> согласиться',
#               'согласится, Mood: Ind -> согласиться',
#               'согласится, Number: Sing -> согласиться',
#               'согласится, Person: 3 -> согласиться',
#               'согласится, Tense: Fut -> согласиться',
#               'осуществляют, Mood: Ind -> осуществлять',
#               'осуществляют, Number: Plur -> осуществлять',
#               'осуществляют, Person: 3 -> осуществлять',
#               'осуществляют, Tense: Pres -> осуществлять',
#               'полагался, Gender: Masc -> зависит',
#               'связану, Mood: Ind -> связанных',
#               'связану, Person: 1 -> связанных',
#               'смог, Gender: Masc -> смогли',
#               'Имел, Gender: Masc -> Имеется',
#               'поняла, Gender: Fem -> понять',
#               'поняла, Mood: Ind -> понять',
#               'поняла, Number: Sing -> понять',
#               'поняла, Tense: Past -> понять',
#               'испорчена, Variant: Short -> испорченной',
#               'имеет, Mood: Ind -> иметь',
#               'имеет, Number: Sing -> иметь',
#               'имеет, Person: 3 -> иметь',
#               'имеет, Tense: Pres -> иметь',
#               'построит, Mood: Ind -> построить',
#               'построит, Number: Sing -> построить',
#               'построит, Person: 3 -> построить',
#               'построит, Tense: Fut -> построить',
#               'описывающий, Gender: Masc -> описывающие',
#               'двигатся, Mood: Ind -> двигаться',
#               'двигатся, Number: Plur -> двигаться',
#               'двигатся, Person: 3 -> двигаться',
#               'двигатся, Tense: Pres -> двигаться',
#               'связаны, Variant: Short -> связанные',
#               'нацелены, Variant: Short -> нацеленные',
#               'решает, Mood: Ind -> решать',
#               'решает, Number: Sing -> решать',
#               'решает, Person: 3 -> решать',
#               'решает, Tense: Pres -> решать',
#               'предлагал, Gender: Masc -> предлагает',
#               'построит, Mood: Ind -> построить',
#               'построит, Number: Sing -> построить',
#               'построит, Person: 3 -> построить',
#               'построит, Tense: Fut -> построить',
#               'определён, Gender: Masc -> определяется',
#               'определён, Variant: Short -> определяется',
#               'застигнуты, Variant: Short -> застигаются',
#               'спорит, Mood: Ind -> спорить',
#               'спорит, Number: Sing -> спорить',
#               'спорит, Person: 3 -> спорить',
#               'спорит, Tense: Pres -> спорить',
#               'влюбится, Mood: Ind -> влюбиться',
#               'влюбится, Number: Sing -> влюбиться',
#               'влюбится, Person: 3 -> влюбиться',
#               'влюбится, Tense: Fut -> влюбиться',
#               'происходят, Mood: Ind -> происходить',
#               'происходят, Number: Plur -> происходить',
#               'происходят, Person: 3 -> происходить',
#               'происходят, Tense: Pres -> происходить',
#               'найдется, Mood: Ind -> найти',
#               'найдется, Number: Sing -> найти',
#               'найдется, Person: 3 -> найти',
#               'найдется, Tense: Fut -> найти',
#               'объяснит, Mood: Ind -> объяснить',
#               'объяснит, Number: Sing -> объяснить',
#               'объяснит, Person: 3 -> объяснить',
#               'объяснит, Tense: Fut -> объяснить',
#               'написано, Gender: Neut -> написанные',
#               'написано, Variant: Short -> написанные',
#               'приняли, Mood: Ind -> принята',
#               'освоится, Mood: Ind -> освоиться',
#               'освоится, Number: Sing -> освоиться',
#               'освоится, Person: 3 -> освоиться',
#               'освоится, Tense: Fut -> освоиться',
#               'научится, Mood: Ind -> научиться',
#               'научится, Number: Sing -> научиться',
#               'научится, Person: 3 -> научиться',
#               'научится, Tense: Fut -> научиться',
#               'задуматся, Mood: Ind -> задуматься',
#               'задуматся, Number: Plur -> задуматься',
#               'задуматся, Person: 3 -> задуматься',
#               'задуматся, Tense: Pres -> задуматься',
#               'кричит, Mood: Ind -> кричат',
#               'кричит, Person: 3 -> кричат',
#               'просвещала, Gender: Fem -> осветили',
#               'превратил, Gender: Masc -> превратили',
#               'отметит, Mood: Ind -> отметить',
#               'отметит, Number: Sing -> отметить',
#               'отметит, Person: 3 -> отметить',
#               'отметит, Tense: Fut -> отметить',
#               'идет, Mood: Ind -> идти',
#               'идет, Number: Sing -> идти',
#               'идет, Person: 3 -> идти',
#               'идет, Tense: Pres -> идти',
#               'Заниматся, Mood: Ind -> Заниматься',
#               'Заниматся, Number: Plur -> Заниматься',
#               'Заниматся, Person: 3 -> Заниматься',
#               'Заниматся, Tense: Pres -> Заниматься',
#               'уливающиеся, Animacy: Inan -> улыбающиеся',
#               'заботится, Mood: Ind -> заботиться',
#               'заботится, Number: Sing -> заботиться',
#               'заботится, Person: 3 -> заботиться',
#               'заботится, Tense: Pres -> заботиться',
#               'относится, Mood: Ind -> относиться',
#               'относится, Number: Sing -> относиться',
#               'относится, Person: 3 -> относиться',
#               'относится, Tense: Pres -> относиться',
#               'корректировал, Gender: Masc -> корректировать',
#               'корректировал, Mood: Ind -> корректировать',
#               'корректировал, Number: Sing -> корректировать',
#               'корректировал, Tense: Past -> корректировать',
#               'опиратся, Mood: Ind -> опираться',
#               'опиратся, Number: Plur -> опираться',
#               'опиратся, Person: 3 -> опираться',
#               'опиратся, Tense: Fut -> опираться',
#               'связаны, Variant: Short -> связанные',
#               'приняли, Mood: Ind -> принята',
#               'уничтоженные, Animacy: Inan -> уничтожены',
#               'уничтоженные, Case: Acc -> уничтожены',
#               'рожается, Person: 3 -> родился',
#               'Построена, Variant: Short -> Построенная',
#               'просочится, Mood: Ind -> просочиться',
#               'просочится, Number: Sing -> просочиться',
#               'просочится, Person: 3 -> просочиться',
#               'просочится, Tense: Fut -> просочиться',
#               'дает, Mood: Ind -> давать',
#               'дает, Number: Sing -> давать',
#               'дает, Person: 3 -> давать',
#               'дает, Tense: Pres -> давать',
#               'варит, Mood: Ind -> варить',
#               'варит, Number: Sing -> варить',
#               'варит, Person: 3 -> варить',
#               'варит, Tense: Pres -> варить',
#               'найдём, Mood: Ind -> найти',
#               'найдём, Number: Plur -> найти',
#               'найдём, Person: 1 -> найти',
#               'найдём, Tense: Fut -> найти',
#               'создалось, Mood: Ind -> создано',
#               'загрязнило, Mood: Ind -> загрязнено',
#               'отправляют, Person: 3 -> отправляли',
#               'пытаюсь, Mood: Ind -> пытаясь',
#               'пытаюсь, Number: Sing -> пытаясь',
#               'пытаюсь, Person: 1 -> пытаясь',
#               'соxраняли, Mood: Ind -> сохранять',
#               'соxраняли, Number: Plur -> сохранять',
#               'соxраняли, Tense: Past -> сохранять',
#               'делает, Mood: Ind -> сделать',
#               'делает, Number: Sing -> сделать',
#               'делает, Person: 3 -> сделать',
#               'делает, Tense: Pres -> сделать',
#               'построил, Gender: Masc -> построили',
#               'направленной, Case: Ins -> направлена',
#               'произносаны, Variant: Short -> произносятся',
#               'использует, Mood: Ind -> использовать',
#               'использует, Number: Sing -> использовать',
#               'использует, Person: 3 -> использовать',
#               'использует, Tense: Pres -> использовать',
#               'продолжала, Gender: Fem -> продолжали',
#               'добится, Mood: Ind -> добиться',
#               'добится, Number: Sing -> добиться',
#               'добится, Person: 3 -> добиться',
#               'добится, Tense: Fut -> добиться',
#               'охраняющий, Animacy: Inan -> охраняющего',
#               'востребованные, Case: Nom -> востребованы',
#               'лидирующей, Gender: Fem -> лидирующие',
#               'обеспечено, Gender: Neut -> обеспечивая',
#               'обеспечено, Number: Sing -> обеспечивая',
#               'обеспечено, Variant: Short -> обеспечивая',
#               'узнал, Gender: Masc -> узнает',
#               'остатся, Mood: Ind -> остаться',
#               'остатся, Number: Plur -> остаться',
#               'остатся, Person: 3 -> остаться',
#               'остатся, Tense: Fut -> остаться',
#               'менятся, Mood: Ind -> меняться',
#               'менятся, Number: Plur -> меняться',
#               'менятся, Person: 3 -> меняться',
#               'менятся, Tense: Fut -> меняться',
#               'понуждается, Mood: Ind -> нуждаться',
#               'понуждается, Number: Sing -> нуждаться',
#               'понуждается, Person: 3 -> нуждаться',
#               'понуждается, Tense: Pres -> нуждаться',
#               'охраняющий, Animacy: Inan -> охраняющего',
#               'отметит, Mood: Ind -> отметить',
#               'отметит, Number: Sing -> отметить',
#               'отметит, Person: 3 -> отметить',
#               'отметит, Tense: Fut -> отметить',
#               'умеет, Mood: Ind -> иметь',
#               'умеет, Number: Sing -> иметь',
#               'умеет, Person: 3 -> иметь',
#               'умеет, Tense: Pres -> иметь',
#               'ругает, Person: 3 -> ругал',
#               'появлятся, Mood: Ind -> применяться',
#               'появлятся, Number: Plur -> применяться',
#               'появлятся, Person: 3 -> применяться',
#               'появлятся, Tense: Pres -> применяться',
#               'объяснит, Mood: Ind -> объяснять',
#               'объяснит, Number: Sing -> объяснять',
#               'объяснит, Person: 3 -> объяснять',
#               'объяснит, Tense: Fut -> объяснять',
#               'рассердится, Mood: Ind -> рассердиться',
#               'рассердится, Number: Sing -> рассердиться',
#               'рассердится, Person: 3 -> рассердиться',
#               'рассердится, Tense: Fut -> рассердиться',
#               'занималось, Gender: Neut -> занимались',
#               'говорит, Mood: Ind -> говорить',
#               'говорит, Number: Sing -> говорить',
#               'говорит, Person: 3 -> говорить',
#               'говорит, Tense: Pres -> говорить',
#               'строит, Mood: Ind -> создавать',
#               'строит, Number: Sing -> создавать',
#               'строит, Person: 3 -> создавать',
#               'строит, Tense: Pres -> создавать',
#               'написан, Variant: Short -> написанным',
#               'вышло, Mood: Ind -> сделано',
#               'стал, Gender: Masc -> стали',
#               'сделано, Gender: Neut -> сделаны',
#               'чувствует, Mood: Ind -> чувствовать',
#               'чувствует, Number: Sing -> чувствовать',
#               'чувствует, Person: 3 -> чувствовать',
#               'чувствует, Tense: Pres -> чувствовать',
#               'наслаждаюсь, Person: 1 -> наслаждалась',
#               'сделано, Gender: Neut -> осуществляется',
#               'сделано, Variant: Short -> осуществляется',
#               'станет, Person: 3 -> стала',
#               'объединена, Gender: Fem -> объединены',
#               'ориентироватся, Mood: Ind -> ориентироваться',
#               'ориентироватся, Number: Plur -> ориентироваться',
#               'ориентироватся, Person: 3 -> ориентироваться',
#               'ориентироватся, Tense: Fut -> ориентироваться',
#               'называемый, Animacy: Inan -> называемые',
#               'называемый, Gender: Masc -> называемые',
#               'развивающиеся, Animacy: Inan -> развивающееся',
#               'связаны, Variant: Short -> связанные',
#               'избран, Variant: Short -> избранный',
#               'вызывал, Gender: Masc -> вызывали',
#               'пялится, Mood: Ind -> пялиться',
#               'пялится, Number: Sing -> пялиться',
#               'пялится, Person: 3 -> пялиться',
#               'пялится, Tense: Fut -> пялиться',
#               'зависит, Mood: Ind -> зависеть',
#               'зависит, Number: Sing -> зависеть',
#               'зависит, Person: 3 -> зависеть',
#               'зависит, Tense: Pres -> зависеть',
#               'переживали, Mood: Ind -> пережив',
#               'переживали, Number: Plur -> пережив',
#               'наносил, Gender: Masc -> наносили',
#               'написан, Variant: Short -> написанным',
#               'помог, Gender: Masc -> помогут',
#               'связана, Variant: Short -> связанная',
#               'Уваличивался, Gender: Masc -> Участились',
#               'рассчитан, Variant: Short -> рассчитанный',
#               'нанесло, Gender: Neut -> нанесли',
#               'найдено, Gender: Neut -> найдены',
#               'завернул, Mood: Ind -> завернутый',
#               'видет, Gender: Masc -> почувствовать',
#               'видет, Number: Sing -> почувствовать',
#               'видет, Tense: Past -> почувствовать',
#               'видет, Variant: Short -> почувствовать',
#               'мог, Gender: Masc -> могу',
#               'связаны, Variant: Short -> связанные',
#               'видела, Gender: Fem -> видеть',
#               'видела, Mood: Ind -> видеть',
#               'видела, Number: Sing -> видеть',
#               'видела, Tense: Past -> видеть',
#               'сохранят, Mood: Ind -> сохранять',
#               'сохранят, Number: Plur -> сохранять',
#               'сохранят, Person: 3 -> сохранять',
#               'сохранят, Tense: Fut -> сохранять',
#               'улучшает, Mood: Ind -> улучшать',
#               'улучшает, Number: Sing -> улучшать',
#               'улучшает, Person: 3 -> улучшать',
#               'улучшает, Tense: Pres -> улучшать',
#               'найдёт, Mood: Ind -> найти',
#               'найдёт, Number: Sing -> найти',
#               'найдёт, Person: 3 -> найти',
#               'найдёт, Tense: Fut -> найти',
#               'учит, Mood: Ind -> учить',
#               'учит, Number: Sing -> учить',
#               'учит, Person: 3 -> учить',
#               'учит, Tense: Pres -> учить',
#               'ушли, Mood: Ind -> ликвидированы',
#               'написана, Variant: Short -> написанной'],
#              'ADJ': ['единственным, Case: Ins -> уникальна',
#               'жива, Gender: Fem -> живы',
#               'плохо, Variant: Short -> плохим',
#               'исследовательские, Animacy: Inan -> исследовательских',
#               'впечатлительные, Case: Nom -> впечатлительны',
#               'актуален, Variant: Short -> актуальный',
#               'известной, Case: Ins -> известна',
#               'общечеловеческая, Gender: Fem -> общечеловеческие',
#               'равные, Case: Nom -> равны',
#               'социального, Gender: Neut -> социальных',
#               'безошибочный, Case: Nom -> безупречен',
#               'сложным, Gender: Masc -> сложными',
#               'скучным, Gender: Masc -> скучными',
#               'жестоким, Gender: Neut -> жестокими',
#               'похож, Gender: Masc -> похожи',
#               'самые, Animacy: Inan -> самое',
#               'политической, Gender: Fem -> политических',
#               'непригодное, Case: Nom -> непригодно',
#               'важно, Variant: Short -> важное',
#               'тяжелая, Case: Nom -> тяжела',
#               'полезные, Case: Nom -> полезны',
#               'важные, Case: Nom -> важны',
#               'новой, Gender: Fem -> новым',
#               'будущие, Animacy: Inan -> будущий',
#               'равные, Animacy: Inan -> равны',
#               'равные, Case: Acc -> равны',
#               'Американский, Gender: Masc -> Американские',
#               'короткие, Animacy: Inan -> коротких',
#               'женский, Animacy: Inan -> женском',
#               'каждые, Animacy: Inan -> каждое',
#               'других, Animacy: Anim -> другим',
#               'великие, Case: Nom -> велики',
#               'мирового, Gender: Masc -> мировых',
#               'равные, Case: Nom -> равны',
#               'сексуального, Gender: Neut -> сексуальных',
#               'самого, Gender: Neut -> самых',
#               'обратный, Animacy: Inan -> обратном',
#               'обычного, Animacy: Anim -> обычное',
#               'междунарожного, Gender: Neut -> международных',
#               'практический, Animacy: Inan -> практичный',
#               'давнейшего, Gender: Masc -> давнейших',
#               'высокопоставленные, Animacy: Inan -> высокопоставленный',
#               'физические, Animacy: Inan -> физических',
#               'теоретические, Animacy: Inan -> теоретических',
#               'неизменную, Gender: Fem -> неизменные',
#               'необходимо, Gender: Neut -> необходимы',
#               'нужны, Variant: Short -> необходимые',
#               'необычные, Animacy: Inan -> необычным',
#               'допольнителные, Animacy: Inan -> дополнительные',
#               'последние, Animacy: Inan -> последнее',
#               'неуместные, Animacy: Inan -> неуместны',
#               'неуместные, Case: Acc -> неуместны',
#               'актуальный, Case: Nom -> актуален',
#               'самого, Gender: Masc -> самих',
#               'последние, Animacy: Inan -> последних',
#               'интересно, Variant: Short -> интересное',
#               'этнического, Gender: Masc -> этнических',
#               'простой, Gender: Fem -> простые',
#               'интелектуальные, Animacy: Inan -> интеллектуальные',
#               'интересные, Case: Nom -> интересны',
#               'реальный, Case: Nom -> реален',
#               'жаргонный, Animacy: Inan -> жаргонную',
#               'рыночного, Gender: Masc -> рыночных',
#               'административные, Animacy: Inan -> административное',
#               'инересная, Case: Nom -> интересна',
#               'медицинского, Gender: Neut -> медицинских',
#               'заподному, Gender: Masc -> западным',
#               'хороший, Animacy: Inan -> хорошее',
#               'выгодная, Case: Nom -> выгодна',
#               'другого, Gender: Neut -> других',
#               'массовое, Gender: Neut -> массовые',
#               'очевидно, Gender: Neut -> очевидны',
#               'этнического, Gender: Neut -> этнические',
#               'Осадочное, Gender: Neut -> Осадочные',
#               'популярном, Gender: Masc -> популярных',
#               'похожо, Variant: Short -> похожее',
#               'достаточные, Case: Nom -> недостаточны',
#               'инновационный, Animacy: Inan -> инновационным',
#               'неизбежные, Case: Nom -> неизбежна',
#               'самые, Animacy: Inan -> самых',
#               'живой, Case: Nom -> жив',
#               'различные, Animacy: Inan -> различных',
#               'кажый, Animacy: Inan -> каждый',
#               'человеческого, Gender: Neut -> человеческих',
#               'коренную, Gender: Fem -> коренные',
#               'Согласный, Case: Nom -> Согласен',
#               'равные, Case: Nom -> равноправны',
#               'нужно, Gender: Neut -> нужны',
#               'любопытные, Case: Nom -> любопытны',
#               'голодным, Gender: Neut -> голодными',
#               'историчная, Case: Nom -> исторична',
#               'экономической, Gender: Fem -> экономических',
#               'счастливым, Case: Ins -> счастливы',
#               'счастливым, Gender: Masc -> счастливы',
#               'необходимы, Variant: Short -> необходимым',
#               'интересно, Variant: Short -> интересным',
#               'сложный, Gender: Masc -> сложных',
#               'постояные, Case: Nom -> постоянны',
#               'счастливые, Case: Nom -> счастливей',
#               'счастливые, Number: Plur -> счастливей',
#               'важнейшие, Case: Nom -> важнее',
#               'важнейшие, Number: Plur -> важнее',
#               'сомнительный, Gender: Masc -> сомнительные',
#               'неспециализированна, Variant: Short -> неспециализированная',
#               'понятно, Gender: Neut -> понятны',
#               'гендерному, Gender: Neut -> гендерным',
#               'важные, Case: Nom -> важны',
#               'прежное, Gender: Neut -> предыдущие',
#               'определоным, Gender: Masc -> определенным',
#               'пибличном, Gender: Neut -> публичных',
#               'одинакова, Variant: Short -> одинаковой',
#               'реальное, Gender: Neut -> реальные',
#               'вредная, Case: Nom -> вредна',
#               'странный, Gender: Masc -> странным',
#               'международном, Gender: Neut -> международных',
#               '19-ого, Animacy: Anim -> 19-ый',
#               'Экологическая, Gender: Fem -> Экологические',
#               'легкий, Animacy: Inan -> легкого',
#               'каждый, Animacy: Inan -> каждую',
#               'последующие, Animacy: Inan -> последующее',
#               'нелюбопытный, Case: Nom -> нелюбопытны',
#               'нелюбопытный, Gender: Masc -> нелюбопытны',
#               'широкий, Animacy: Inan -> широком',
#               'двусмысленное, Gender: Neut -> двусмысленными',
#               'опасные, Case: Nom -> опасны',
#               'готовые, Case: Nom -> готовы',
#               'общественные, Animacy: Inan -> общественными',
#               'сексуального, Gender: Neut -> сексуальных',
#               'приятные, Animacy: Inan -> приятны',
#               'приятные, Case: Acc -> приятны',
#               'похожие, Gender: Neut -> похожими',
#               'самые, Animacy: Inan -> самое',
#               'публичном, Gender: Masc -> публичных',
#               'очевидное, Case: Nom -> очевидно',
#               'последний, Animacy: Inan -> предыдущем',
#               'вреные, Animacy: Inan -> вредные',
#               'скромный, Animacy: Inan -> скромным',
#               'новый, Animacy: Inan -> новое',
#               'серьезный, Case: Nom -> серьезен',
#               'эмоционально-психические, Animacy: Inan -> эмоционально-психическими',
#               'разная, Case: Nom -> различна',
#               'односторонние, Animacy: Inan -> односторонним',
#               'хорошо, Variant: Short -> хорошее',
#               'выгодно, Variant: Short -> выгодным',
#               'дешёвый, Animacy: Inan -> дешевую',
#               'хорошо, Variant: Short -> хорошее',
#               'третий, Animacy: Inan -> третьей',
#               'послушны, Variant: Short -> послушного',
#               'счастливы, Variant: Short -> счастливыми',
#               'мирны, Variant: Short -> мирными',
#               'понятно, Variant: Short -> понятное',
#               'плохо, Variant: Short -> плохое',
#               'Каждые, Animacy: Inan -> Каждый',
#               'нетрадиционного, Gender: Neut -> нетрадиционных',
#               'физический, Animacy: Inan -> физическим',
#               'известным, Case: Ins -> известно',
#               'избирательное, Gender: Neut -> избирательных',
#               'опасная, Case: Nom -> опасна',
#               'вредно, Variant: Short -> вредном',
#               'стильным, Gender: Masc -> стильными',
#               'красивым, Gender: Masc -> красивыми',
#               'необычным, Gender: Masc -> необычными',
#               'эффектным, Gender: Masc -> эффектными',
#               'глубокий, Gender: Masc -> глубокие',
#               'Самый, Gender: Masc -> Самые',
#               'первый, Gender: Masc -> первые',
#               'русский, Animacy: Inan -> русского',
#               'добровольна, Variant: Short -> добровольной',
#               'третих, Gender: Masc -> третьих',
#               'третих, Variant: Short -> третьих',
#               'большие, Animacy: Inan -> большим',
#               'водны, Variant: Short -> водный',
#               'долгий, Animacy: Inan -> долгого',
#               'новой, Gender: Fem -> новые',
#               'таверна, Gender: Fem -> таверны',
#               'безопасная, Case: Nom -> безопасна',
#               'интересные, Case: Nom -> интересны',
#               'непонятные, Case: Nom -> непонятны',
#               'ненадежные, Case: Nom -> ненадежны',
#               'последние, Animacy: Inan -> последним',
#               'мировые, Animacy: Inan -> мировым',
#               'нужные, Case: Nom -> нужны',
#               'общая, Gender: Fem -> общие',
#               'самым, Gender: Masc -> самых',
#               'дорогим, Gender: Masc -> дорогих',
#               'каждой, Gender: Fem -> других',
#               'важные, Animacy: Inan -> важную',
#               'ядерный, Animacy: Inan -> ядерного',
#               'капиталистическим, Gender: Masc -> капиталистическими',
#               'спациального, Animacy: Anim -> спациального',
#               'Административном, Case: Loc -> Административно',
#               'Административном, Gender: Neut -> Административно',
#               'Административном, Number: Sing -> Административно',
#               'самоувереный, Case: Nom -> уверен',
#               'глубокое, Gender: Neut -> глубокие',
#               'бывшим, Gender: Masc -> бывшими',
#               'похвальные, Animacy: Inan -> разумной',
#               'российский, Gender: Masc -> российские',
#               'профессиональна, Variant: Short -> профессиональной',
#               'позитивный, Animacy: Inan -> позитивного',
#               'техный, Animacy: Inan -> тесных',
#               'техный, Gender: Masc -> тесных',
#               'финансовые, Animacy: Inan -> финансовой',
#               'долгие, Animacy: Inan -> долгое',
#               'язвительным, Gender: Masc -> язвительных',
#               'социальным, Gender: Masc -> социальных',
#               'прекрасная, Case: Nom -> прекрасна',
#               'странно, Variant: Short -> странным',
#               'безопастная, Case: Nom -> безопасна',
#               'грунтовой, Gender: Fem -> грунтовых',
#               'известным, Case: Ins -> известен',
#               'стабильная, Case: Nom -> стабильна',
#               'вероятный, Case: Nom -> вероятен',
#               'беднее, Gender: Neut -> бедным',
#               'типичный, Case: Nom -> типичен',
#               'бывшей, Gender: Fem -> бывших',
#               'просто, Variant: Short -> простой',
#               'равна, Variant: Short -> равной',
#               'важные, Animacy: Inan -> важным',
#               'избирательное, Gender: Neut -> избирательных',
#               'многообразные, Animacy: Inan -> многообразным',
#               'огромное, Case: Nom -> огромно',
#               'заметные, Animacy: Inan -> интересные',
#               'дальнейшие, Animacy: Inan -> дальнейшее',
#               'гибким, Gender: Masc -> гибкими',
#               'успешным, Gender: Masc -> успешными',
#               'общественной, Gender: Fem -> общественных',
#               'арочный, Animacy: Inan -> арочное',
#               'важная, Case: Nom -> важна',
#               'хорошое, Gender: Neut -> хорошие',
#               'Экономические, Animacy: Inan -> Экономическое',
#               'здоровый, Case: Nom -> здоровы',
#               'здоровый, Gender: Masc -> здоровы',
#               'внутренний, Animacy: Inan -> внутренней',
#               'нужен, Gender: Masc -> нужны',
#               'необходимо, Variant: Short -> необходимое',
#               'здоровым, Gender: Masc -> здоровыми',
#               'молодые, Case: Nom -> молоды',
#               'гуманитарный, Gender: Masc -> гуманитарные',
#               'известным, Case: Ins -> известно',
#               'способные, Case: Nom -> способны',
#               'злое, Case: Nom -> недопустимо'],
#              'DET': ['какое, Gender: Neut -> какие',
#               'свой, Gender: Masc -> свои',
#               'тот, Gender: Masc -> тех',
#               'свое, Gender: Neut -> свои',
#               'этой, Gender: Fem -> этих',
#               'всё, Gender: Neut -> все',
#               'наше, Gender: Neut -> наши',
#               'этой, Gender: Fem -> этих',
#               'никакое, Gender: Neut -> никаких'],
#              'PRON': ['он, Person: 3 -> это',
#               'нем, Gender: Masc -> них',
#               'её, Animacy: Inan -> нем',
#               'это, Animacy: Inan -> оно',
#               'ее, Gender: Fem -> их',
#               'это, Animacy: Inan -> оно',
#               'он, Gender: Masc -> они',
#               'этим, Animacy: Inan -> ним',
#               'этим, Gender: Neut -> ним',
#               'он, Person: 3 -> это',
#               'его, Gender: Masc -> им',
#               'его, Person: 3 -> этого',
#               'Это, Animacy: Inan -> Оно',
#               'он, Person: 3 -> это',
#               'это, Animacy: Inan -> он',
#               'это, Animacy: Inan -> он'],
#              'AUX': ['был, Gender: Masc -> были',
#               'была, Gender: Fem -> были',
#               'была, Gender: Fem -> были',
#               'было, Gender: Neut -> были',
#               'была, Gender: Fem -> были',
#               'была, Gender: Fem -> были'],
#              'NUM': ['несколько, Animacy: Inan -> нескольких',
#               'несколько, Animacy: Inan -> нескольких',
#               'обе, Animacy: Inan -> обеих',
#               'две, Animacy: Inan -> двух',
#               'две, Gender: Fem -> двух',
#               'несколько, Animacy: Inan -> несколькими',
#               'несколько, Animacy: Inan -> нескольких',
#               'два, Animacy: Inan -> двух',
#               'два, Gender: Masc -> двух',
#               'несколько, Animacy: Inan -> нескольких',
#               'несколько, Animacy: Inan -> нескольких',
#               'два, Animacy: Inan -> две',
#               'несколько, Animacy: Inan -> нескольких'],
#              'PROPN': ['Министерства, Animacy: Inan -> Ministerstvo',
#               'Министерства, Case: Gen -> Ministerstvo',
#               'Министерства, Gender: Neut -> Ministerstvo',
#               'Министерства, Number: Sing -> Ministerstvo'],
#              'ADV': ['несмотря, Polarity: Neg -> независимо']})

# %%
# Save the full report as JSON
report = {}
report['additions_pos_stats'] = additions_pos_stats
report['additions_rel_stats'] = additions_rel_stats
report['deletions_pos_stats'] = deletions_pos_stats
report['deletions_rel_stats'] = deletions_rel_stats
report['pos_mismatches'] = pos_mismatches
report['rel_mismatches'] = rel_mismatches
report['feature_mismatches'] = feature_mismatches

with open('report.json', 'w') as out:
    json.dump(report, out, indent=2, ensure_ascii=False)

# %%
# Save feature-mismatch matrices
f = open('feature_mismatches.txt', 'w')
for pos in feature_mismatches:
    print(pos, file=f)
    for feature in feature_mismatches[pos]:
        inp = []
        out = []
        print(f'\t{feature}', file=f)
        for pair in feature_mismatches[pos][feature]:
            a, b = pair
            inp.append(a)
            out.append(b)
        df_tmp = pd.DataFrame({
            'inp': inp,
            'out': out
        })
        cm = pd.crosstab(df_tmp['inp'], df_tmp['out'])
        print(cm.to_string(), file=f)
        print('', file=f)
f.close()

# %%
def query_feature_mismatch(aligned_graphs,
                           pos,
                           feature,
                           val1='any',
                           val2='any'):
    errors = 0
    for ags in aligned_graphs:
        al_dict = ags['align']
        if no_corrections(al_dict):
            continue
        for k, v in al_dict.items():
            if k == 'X' or v == 'X':
                continue
            i = str(k+1)
            j = str(v['idx']+1)
            try:
                inp_n = ags['inp_n'][i]
                inp_feats = inp_n['features']
                out_n = ags['out_n'][j]
                out_feats = out_n['features']
                f = feature
                if f in inp_feats \
                and f in out_feats \
                and inp_feats[f] != out_feats[f]:
                    if (inp_feats[f] == val1 or val1 == 'any') \
                    and (out_feats[f] == val2 or val2 == 'any'):
                        print(
                            f'{inp_n["wordform"]},{f}:{inp_feats[f]} -> {out_n["wordform"]},{f}:{out_feats[f]}'
                        )
                        keys = sorted(ags['inp_n'])
                        print(' '.join(ags['inp_n'][k]['wordform'] for k in keys))
                        keys = sorted(ags['out_n'])
                        print(' '.join(ags['out_n'][k]['wordform'] for k in keys))
                        print()
            except KeyError:
                errors += 1
                continue
    return errors

# %%
query_feature_mismatch(aligned_graphs,
                      'VERB',
                      'Voice',
                      'Act',
                      'Pass')
# Out:
# придумав,Voice:Act -> придуманный,Voice:Pass
# Его " , придумав Ред Уассенич в 2000-ом году в Аустине базировали , Техасе , по той же причене . на модели лозунга " Keep Austin Weird
# Он " , придуманный Ред Уассенич в 2000-ом году в Аустине основан , штат Техас по той же причине . на модели лозунга " Keep Austin Weird
#
# загрязнают,Voice:Act -> загрязняются,Voice:Pass
# Загрязняются океаны нефтом и контейнером с радиоактивными отходами . моря промышленным и радиоактивным мусором , и загрязнают
# Загрязняются океаны нефтью и контейнером с радиоактивными отходами . моря промышленным и радиоактивным мусором , и загрязняются
#
# тратившими,Voice:Act -> потраченными,Voice:Pass
# И хорошие корпорации и негосударственные организации . много раз с избирательными долларами , тратившими в
# И корпорации и негосударственные организации . много раз избирательными долларами , потраченными в хорошие
#
# принимает,Voice:Act -> принимаются,Voice:Pass
# Когда что принимает часто по-своему ( просвещённый абсолютизм ) , обычно принимает поздно , резко и иногда с чувством сожаления ( Александр реформы III ) см . за счет многих жизней , потому
# Иногда что реформы принимаются часто по-своему ( просвещённый абсолютизм ) , реформы обычно поздно , резко и иногда с чувством сожаления ( принимаются Александр III ) см . за счет многих жизней , потому
#
# принимает,Voice:Act -> принимаются,Voice:Pass
# Когда что принимает часто по-своему ( просвещённый абсолютизм ) , обычно принимает поздно , резко и иногда с чувством сожаления ( Александр реформы III ) см . за счет многих жизней , потому
# Иногда что реформы принимаются часто по-своему ( просвещённый абсолютизм ) , реформы обычно поздно , резко и иногда с чувством сожаления ( принимаются Александр III ) см . за счет многих жизней , потому
#
# считаютя,Voice:Act -> считаются,Voice:Pass
# Мне такими цветами , которые считаютя " женскими " . было интересно , что фирма решила только рекламировать
# Мне такие цвета , которые считаются " женскими " . было интересно , что фирма решила только рекламировать
#
# принимают,Voice:Act -> принимаются,Voice:Pass
# Он таких как Германии , Франции и США , Выпускники переводческого также факультета принимают работу на такие организации как ООН и ЮНЕСКО сотрудничает . с вузами во многоих странах ,
# Он таких как Германии , Франции и США , Выпускники переводческого также факультета принимаются работу такими организациями как ООН и ЮНЕСКО . сотрудничает с вузами во многих странах ,
#
# устроить,Voice:Act -> устраиваемые,Voice:Pass
# Экономики ослабляет проекты устроить инновационный сектор и . считают , что эта препятствует диверсификацию экономики и
# Экономисты ослабляет проекты , устраиваемые инновационным сектором и . считают , что эта препятствует диверсификации экономики и
#
# регулирует,Voice:Act -> регулируется,Voice:Pass
# Главная регулирует никаких властей . проблема заключается в том , что процесс не
# Главная не регулируется никакими властями . проблема заключается в том , что этот процесс
#
# связану,Voice:Act -> связанных,Voice:Pass
# Экономика морем . Аральского региона полагался на работу , связану с
# Экономика морем . Аральского региона зависит от работ , связанных с
#
# преграждает,Voice:Act -> преграждается,Voice:Pass
# В и преграждает свет от водных растений . результате , она задыхается рыб , отягощает птиц
# В преграждается свет к водным растениям . результате , задыхаются рыбы , отягощаются птицы и
#
# приняли,Voice:Act -> принята,Voice:Pass
# Политическая система приняли от европейской модели
# Политическая система принята по европейской модели
#
# возвращало,Voice:Act -> возвращалось,Voice:Pass
# В - право варить пиво возвращало и идея из зелёной революции 70-ых распространена в домашнее и ремесленное пивоварение . остальные федеральные законы против пива были разъяснены
# В - право варить пиво возвращалось и идея зелёной революции была 70-ых распространена в домашнее и ремесленное пивоварение . остальные федеральные законы против пива были разъяснены
#
# кричит,Voice:Act -> кричат,Voice:Pass
# Американцы в общем , не показывают свои эмоции так открыто как обычно люди в России . не кричит друг на друга и ,
# Американцы в общем , не показывают свои эмоции так открыто , обычно как люди в России . не кричат друг на друга и ,
#
# приняли,Voice:Act -> принята,Voice:Pass
# Система образование приняли от европейской модели
# Система образования принята по европейской модели
#
# выбравшего,Voice:Act -> выбранного,Voice:Pass
# Ученики курса , выбравшего учениками или их родителями . делятся на отдельные группы , которые зависят от
# Ученики курса , выбранного учениками или их родителями . делятся на отдельные группы , которые зависят от
#
# снимавшие,Voice:Act -> снимавшиеся,Voice:Pass
# Самые » - итальянские вестерны в поджанре киновестернов , снимавшие в известные Италии . из них – так называемые « спагетти-вестерны
# Самые » - итальянские вестерны в поджанре киновестернов , снимавшиеся в известные Италии . из них – так называемые « спагетти-вестерны
#
# загрязнило,Voice:Act -> загрязнено,Voice:Pass
# На части Байкала – в случае рарыва нефтепровода от землетрасения или пример от другой аварии , всё озеро было бы загрязнило . , промышленники хотели строить нефтепровод на прибрежной
# Например Байкала – в случае разрыва нефтепровода от землетрясения или от , другой аварии , всё озеро было бы загрязнено . промышленники хотели строить нефтепровод на прибрежной части
#
# играющей,Voice:Act -> играемой,Voice:Pass
# На нем музыке . сайте можно найти много информаций об играющей на
# На нем музыке . сайте можно найти много информации об играемой на
#
# есть,Voice:Act -> используется,Voice:Pass
# Теперь в случае разрыва есть трубопровод теплоносителя . на станции использует оболочки для реакторного цеха и
# Теперь в случае разрыва используется трубопровод теплоносителя . на станции используют оболочки для реакторного цеха и
#
# есть,Voice:Act -> наблюдается,Voice:Pass
# Хотя местах есть совсем другая ситуация . нам очень удобно в Портленде , в других
# Хотя местах наблюдается совсем другая ситуация . нам очень удобно в Портленде , в других
#
# приходят,Voice:Act -> определяется,Voice:Pass
# Наша планы – все от них довольно часто приходят . моральная структура , иногда наша профессия , наши
# Наша планы – все это довольно часто определяется влиянием семьи и моральная родителей . структура , иногда наша профессия , наши
#
# вышло,Voice:Act -> сделано,Voice:Pass
# Из достижений и мировых знаменитостей в различных областях . стен университета вышло огромное количество научных открытий и
# В достижений и из него вышло много мировых знаменитостей в различных стенах областях . университета сделано огромное количество научных открытий и
#
# завернул,Voice:Act -> завернутый,Voice:Pass
# Потом вон ! Лазарь появился , живой , завернул в полотне Он . призвал к Лазаря и сказал , иди
# Потом ! Лазарь появился , живой , завернутый в полотно . Он призвал Лазаря и сказал , иди вон
#
# ушли,Voice:Act -> ликвидированы,Voice:Pass
# Они с новыми , передовыми способами конструкции , это не значит заявили , что все опасности ушли . , что даже если АЭС была построена
# Они построена с новыми , передовыми способами конструкции , это не заявили значит , что все опасности ликвидированы . , что , даже если АЭС была
# 5
